# %%
import pandas as pd
import nltk # 자연어 처리 패키지

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
all_data = pd.read_csv('riss_bigdata.csv')
all_title = all_data['제목']
all_title
# Out:
# 0     Big Data in Healthcare: Opportunities and Chal...
# 1     Combining Human Computing and Machine Learning...
# 2                          Big data (lost) in the cloud
# 3     Big Earth data: A new frontier in Earth and in...
# 4     Common Big Data Challenges and How to Overcome...
#                             ...
# 95    Big-BOE: Fusing Spanish Official Gazette with ...
# 96    Resting-State fMRI Functional Connectivity: Bi...
# 97    A reference architecture for big data solution...
# 98    Thermal-Aware and DVFS-Enabled Big Data Task S...
# 99    Call for Papers: Special Issue on Big Data in ...
# Name: 제목, Length: 100, dtype: object

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re

stopWords = set(stopwords.words('english')) #NLTK가 정의한 영어 불용어 리스트
lemma = WordNetLemmatizer() # 표제어 추출 객체
words = []

for title in all_title:
#     print(title)
    enWords = re.sub(r'[^a-zA-z]',' ',str(title)) #영어가 아닌 것 '' 대체
    enWordsToken = word_tokenize(enWords.lower()) # 소문자로
    enWordsTokenStop = [w for w in enWordsToken if w not in stopWords]
    enWordsTokenStopLemma = [lemma.lemmatize(w) for w in enWordsToken]
    words.append(enWordsTokenStopLemma)
print(words)
# Out:
# [['big', 'data', 'in', 'healthcare', 'opportunity', 'and', 'challenge'], ['combining', 'human', 'computing', 'and', 'machine', 'learning', 'to', 'make', 'sense', 'of', 'big', 'aerial', 'data', 'for', 'disaster', 'response'], ['big', 'data', 'lost', 'in', 'the', 'cloud'], ['big', 'earth', 'data', 'a', 'new', 'frontier', 'in', 'earth', 'and', 'information', 'science'], ['common', 'big', 'data', 'challenge', 'and', 'how', 'to', 'overcome', 'them'], ['stgi', 'a', 'spatio', 'temporal', 'grid', 'index', 'model', 'for', 'marine', 'big', 'data'], ['tv', 'audience', 'measurement', 'with', 'big', 'data'], ['the', 'u', 's', 'army', 'person', 'event', 'data', 'environment', 'a', 'military', 'civilian', 'big', 'data', 'enterprise'], ['doe', 'medical', 'school', 'training', 'relate', 'to', 'practice', 'evidence', 'from', 'big', 'data'], ['an', 'exercise', 'in', 'exploring', 'big', 'data', 'for', 'producing', 'reliable', 'statistical', 'information'], ['gsio', 'a', 'programmatic', 'interface', 'for
# ...

# %%
#전처리가 끝난 words 를 1차원 list
from functools import reduce
words2 = list(reduce(lambda x , y:x+y, words))
words2
# Out:
# ['big',
#  'data',
#  'in',
#  'healthcare',
#  'opportunity',
#  'and',
#  'challenge',
#  'combining',
#  'human',
#  'computing',
#  'and',
#  'machine',
#  'learning',
#  'to',
#  'make',
#  'sense',
#  'of',
#  'big',
#  'aerial',
#  'data',
#  'for',
#  'disaster',
#  'response',
#  'big',
#  'data',
#  'lost',
#  'in',
#  'the',
#  'cloud',
#  'big',
#  'earth',
#  'data',
#  'a',
#  'new',
#  'frontier',
#  'in',
#  'earth',
#  'and',
#  'information',
#  'science',
#  'common',
#  'big',
#  'data',
#  'challenge',
#  'and',
#  'how',
#  'to',
#  'overcome',
#  'them',
#  'stgi',
#  'a',
#  'spatio',
#  'temporal',
#  'grid',
#  'index',
#  'model',
#  'for',
#  'marine',
#  'big',
#  'data',
#  'tv',
#  'audience',
#  'measurement',
#  'with',
#  'big',
#  'data',
#  'the',
#  'u',
#  's',
#  'army',
#  'person',
#  'event',
#  'data',
#  'environment',
#  'a',
#  'military',
#  'civilian',
#  'big',
#  'data',
#  'enterprise',
#  'doe',
#  'medical',
#  'school',
# ...

# %%
# 단어 빈도 구하기
from collections import Counter
count = Counter(words2)
count
# Out:
# Counter({'big': 104,
#          'data': 116,
#          'in': 28,
#          'healthcare': 2,
#          'opportunity': 2,
#          'and': 37,
#          'challenge': 6,
#          'combining': 1,
#          'human': 4,
#          'computing': 2,
#          'machine': 3,
#          'learning': 3,
#          'to': 15,
#          'make': 1,
#          'sense': 1,
#          'of': 26,
#          'aerial': 1,
#          'for': 35,
#          'disaster': 1,
#          'response': 2,
#          'lost': 2,
#          'the': 28,
#          'cloud': 3,
#          'earth': 18,
#          'a': 32,
#          'new': 5,
#          'frontier': 2,
#          'information': 3,
#          'science': 6,
#          'common': 1,
#          'how': 1,
#          'overcome': 1,
#          'them': 1,
#          'stgi': 1,
#          'spatio': 1,
#          'temporal': 1,
#          'grid': 1,
#          'index': 1,
#          'model': 5,
#          'marine': 1,
#          'tv': 1,
# ...

# %%
# 상위 50개 단어 딕셔너리에 저장
word_count = dict()
# count.most_common(10)
for tag, counts in count.most_common(50):
    if len(str(tag)) >1 :
        word_count[tag] = counts
word_count
# Out:
# {'data': 116,
#  'big': 104,
#  'and': 37,
#  'for': 35,
#  'in': 28,
#  'the': 28,
#  'of': 26,
#  'earth': 18,
#  'analytics': 16,
#  'to': 15,
#  'on': 15,
#  'with': 9,
#  'based': 9,
#  'analysis': 8,
#  'issue': 7,
#  'challenge': 6,
#  'science': 6,
#  'call': 6,
#  'special': 6,
#  'paper': 6,
#  'new': 5,
#  'model': 5,
#  'an': 5,
#  'using': 5,
#  'health': 5,
#  'human': 4,
#  'from': 4,
#  'research': 4,
#  'processing': 4,
#  'approach': 4,
#  'perspective': 4,
#  'market': 4,
#  'it': 4,
#  'review': 4,
#  'machine': 3,
#  'learning': 3,
#  'cloud': 3,
#  'information': 3,
#  'web': 3,
#  'scientific': 3,
#  'classification': 3,
#  'computational': 3,
#  'propaganda': 3,
#  'political': 3,
#  'search': 3,
#  'global': 3,
#  'education': 3,
#  'survey': 3,
#  'driven': 3}

# %%
import matplotlib.pyplot as plt

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorte_Values = sorted(word_count.values(), reverse=True)
sorte_Values

plt.bar(range(len(word_count)),sorted_Values, align='center')
plt.xticks(range(len(word_count)),list(sorted_Keys),rotation='85')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6592\2818306151.py in <module>
#       4 sorte_Values = sorted(word_count.values(), reverse=True)
#       5 sorte_Values
# ----> 6 plt.bar(range(len(word_count)),sorted_Values, align='center')
#       7
#       8 # plt.xticks(range(len(word_count)),list(sorted_Keys),rotation='85')
#
# NameError: name 'sorted_Values' is not defined

# %%
del word_count['big']
del word_count['data']

# %%
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorte_Values = sorted(word_count.values(), reverse=True)
sorte_Values
plt.bar(range(len(word_count)),sorted_Values, align='center')
# plt.xticks(range(len(word_count)),list(sorted_Keys),rotation='85')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6592\2644893238.py in <module>
#       2 sorte_Values = sorted(word_count.values(), reverse=True)
#       3 sorte_Values
# ----> 4 plt.bar(range(len(word_count)),sorted_Values, align='center')
#       5 # plt.xticks(range(len(word_count)),list(sorted_Keys),rotation='85')
#       6 # plt.show()
#
# NameError: name 'sorted_Values' is not defined

# %%
# 워드 클라우드 그리기
from wordclout import STOPWORDS,WordCloud
stopwords = set(STOPWORDS)
wc = WordCloud(background_color='ivory',stopwords = stopwords,
             width=800,height=600)
cloud = wc.generate_from_requencies(word_count)
# cloud
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()
cloud.to_file('eng_)wordCloud.jpg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6592\3083916076.py in <module>
#       1 # 워드 클라우드 그리기
# ----> 2 from WordCloud import STOPWORDS,WordCloud
#       3 stopwords = set(STOPWORDS)
#       4 wc = WordCloud(background_color='ivory',stopwords = stopwords,
#       5              width=800,height=600)
#
# ModuleNotFoundError: No module named 'WordCloud'
